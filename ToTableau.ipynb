# %%
import pandas as pd
import sqlite3
import numpy

dbfile = "FinalAfter.db"

con = sqlite3.connect(dbfile)
DF = pd.read_sql_query('select * from Total2008', con)

DF.to_csv('TotalEC2008.csv')

# %%
import pandas as pd
import sqlite3
import numpy

dbfile = "FinalAfter.db"

con = sqlite3.connect(dbfile)
DF = pd.read_sql_query('select * from Total2012', con)

DF.to_csv('TotalEC2012.csv')

# %%
import pandas as pd
import sqlite3
import numpy

dbfile = "FinalAfter.db"

con = sqlite3.connect(dbfile)
DF = pd.read_sql_query('select * from Total2016', con)

DF.to_csv('TotalEC2016.csv')

# %%
import pandas as pd
import sqlite3
import numpy

dbfile = "FinalAfter.db"

con = sqlite3.connect(dbfile)
DF = pd.read_sql_query('select * from Total2020', con)

DF.to_csv('TotalEC2020.csv')
